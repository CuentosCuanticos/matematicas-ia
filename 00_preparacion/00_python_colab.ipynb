# %% [markdown]
# <a href="https://colab.research.google.com/github/CuentosCuanticos/matematicas-ia/blob/main/00_preparacion/00_python_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matemáticas de la Inteligencia Artificial
#
# ## Cuaderno 00 — Preparación del entorno
#
# **Cuentos Cuánticos**

# %% [markdown]
# ## 1. Comprobación del entorno
#
# Antes de comenzar, verificamos que Colab dispone de las bibliotecas fundamentales que utilizaremos durante el curso.
#
# No es necesario instalar Python ni configurar un entorno local: los laboratorios están diseñados para ejecutarse directamente en Google Colab.

# %%
import sys
import numpy as np
import torch

print("Python:", sys.version.split()[0])
print("NumPy:", np.__version__)
print("PyTorch:", torch.__version__)
print("GPU disponible:", torch.cuda.is_available())
# Out:
# Python: 3.13.15
# NumPy: 2.1.3
# PyTorch: 2.11.0+cpu
# GPU disponible: False

# %% [markdown]
# ## 2. Flujo de trabajo del alumno
#
# Cada laboratorio del curso seguirá siempre el mismo recorrido:
#
# 1. Abrir el cuaderno oficial desde GitHub.
# 2. Pulsar **«Copiar en Drive»**.
# 3. Trabajar únicamente sobre esa copia personal.
# 4. Ejecutar las celdas de arriba abajo.
# 5. Guardar el cuaderno terminado para su entrega en Moodle.
#
# La versión de GitHub actúa como **versión oficial del curso** y no debe modificarse directamente por el alumno.
